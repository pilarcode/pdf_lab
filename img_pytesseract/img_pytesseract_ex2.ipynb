# %% [markdown]
# ### tesseract
#
# [tesseract](https://github.com/tesseract-ocr/tesseract)

# %%
image_path = "../070ZNNLE73289_S1097.png"

# %%
import pytesseract
from PIL import Image

def ocr_core(filename):
    """
    This function will handle the core OCR processing of images.
    """
    
    # Specify the path to the Tesseract executable
    pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
    text = pytesseract.image_to_string(Image.open(filename))  
    return text

text = ocr_core(image_path)
print(text)
# Out:
# os
#
# SH-DSLVYNG
# WIDNATWA
# SaYOLOW
#
# |
#
# NOIDVZINOSN3S
#
# conewnan wneud
#
# ‘oyjnexpi/a4inexpAh
#
# efonfpaug
#
# SaIVIdsLVW 3d Vis
#
# 68ZEZ-31-NN-Z-020
#
# Fy
# 3
# 8
# 2
# fs
# iS
# 8
# Fa
# IS
# 8
#
# omeuiwouaa/an
#
# Para Mantenimiento
#
# Type:Order No: Drawing no: Standard Reference Diagramm, Diagram EG,
#
# Description Cay Required Techn. Data. e.g. Control Voltage. ete Gege en
# Descripcion Fabricante Notes
#
# Referencia Notas
# Tipo.No -Pedido:No.-Plano:ref. Standard
#
# Datos Tecnicos Requerides: e}:Control, voltaje.
#
# Designacion
# en el Plano
#
# Quantity
# No. Piezas
#
# RELE AUXIN SIEMENS siz 31-18640
# CONTACTO AUXLIAR SIEMENS 29 1-1FAao [Passe
# VARISTOR SIEMENS 2 1618800 rasta
#
# RELE AUXILIAR
#
# VARISTOR
# RELE AUXILIAR
#
# VARISTOR
#
# SIEMENS KA5209
# ‘SIEMENS
#
# SIEMENS
#
# 3RH2131-18840
# 3RT29 16-18800 KA5209
# 3RH2131-18840 Kas212
#
# SIEMENS 3RT29 16-18600 kas212
#
# [|
# [|
# LI
#
# rot a1-18840 a ren
# [|
# [|
#
# 46) RELE AUXILIAR SIEMENS
#
# Kas613
#
# 3RH2131-18840
# KASBI6
# Kasoi2
# Pafvarstor df stewens aero setonon caso ica
# fzfrcieauumar siemens ates atpnco casos inte
# fz[varistor stews aerzose-toe00 casos icone
# fzfrceauumr i siewens ation atpeco tons iss
# fzfreeavumr siemens azn atpeco ceases
# fz variston — siewens area retapoo casio i
# zafreverarowusito feuz swe xipoczosy two
# fz[reicraronusuo fruzrsweximroczosy tne once
# sof ree raRoHusILO uz swe xipcoczosy tae asc |
# PSWZ IP (0,02-0.5V) Keas02 es a
# itz PSW2 X1P (002-050) aoe a a es
#
# KA5616
#
# PSWZ X1P (0,02-0.5V)
#
# PILZ A602
#
# neo [
# oF 910
# nasi kai
# asxveri 701
#
# PSWZ X1P (0,02-0.5V)
# Piz PSWZ XP (0,02-0.5V)
# EATON PART No NZM2
# PHOENIX CONTACT
#
# BOSCH REXROTH
#
# PART No 2067840
#
# INDRADRIVE COMPACT CONVERTER PART No HCS0S.1E-W0150-A-05-NNNN,
